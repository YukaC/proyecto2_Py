# %%
# Importar el módulo fotoapp con las funciones definidas
import fotoapp as fa
# Ruta de la imagen de prueba 
ruta_imagen = "fotos_originales/imagen_prueba.jpg"


# Prueba de la función 1: Redimensionar una imagen para una plataforma específica
print("Prueba de redimensionamiento de imagen para Instagram:")
imagen_redimensionada = fa.redimensionar_imagen(ruta_imagen, "instagram")
# Out:
# Prueba de redimensionamiento de imagen para Instagram:

# %%
# Prueba de la función 2: Ajustar contraste de una imagen
print("Prueba de ajuste de contraste:")
imagen_contraste = fa.ajustar_contraste_histograma()
# Out:
# Prueba de ajuste de contraste:

# %%
# Prueba de la función 3: Aplicar un filtro a una imagen
print("Prueba de aplicación de filtro 'desenfoque':")
imagen_filtrada = fa.aplicar_filtro()
# Out:
# Prueba de aplicación de filtro 'desenfoque':
# Filtros disponibles: original, desenfoque, contorno, detalle, realce_bordes, realce_bordes_mayor, relieve, encontrar_bordes, afilar, suavizar
# Ingrese el filtro a aplicar:  desenfoque

# %%
# Prueba de la función 4: Crear un boceto para pintores
print("Prueba de creación de boceto para pintores (suponiendo que la imagen contiene una persona):") 
imagen_boceto = fa.boceto_para_pintores(ruta_imagen)
# Out:
# Prueba de creación de boceto para pintores (suponiendo que la imagen contiene una persona):
